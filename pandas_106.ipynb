# %% [markdown]
# <a href="https://colab.research.google.com/github/Rstam59/TaskDataRepoForStudents/blob/main/pandas_106.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

cars = pd.Series(['Bugatti', 'Ferrari', 'Lamborghini'])
cars
# Out:
# 0        Bugatti
# 1        Ferrari
# 2    Lamborghini
# dtype: object

# %%
colors = pd.Series(['Red', 'Blue', 'White'])
colors
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
type(colors)
# Out:
# pandas.core.series.Series

# %%
cars = pd.DataFrame({'Car': cars, 'Color': colors})
cars
# Out:
#            Car  Color
# 0      Bugatti    Red
# 1      Ferrari   Blue
# 2  Lamborghini  White

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales.csv
# Out:
# --2024-06-25 06:10:09--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-06-25 06:10:10 (5.33 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
car_sales = pd.read_csv('/content/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[['Make', 'Colour']]
# Out:
#      Make Colour
# 0  Toyota  White
# 1   Honda    Red
# 2  Toyota   Blue
# 3     BMW  Black
# 4  Nissan  White
# 5  Toyota  Green
# 6   Honda   Blue
# 7   Honda   Blue
# 8  Toyota  White
# 9  Nissan  White

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# @title Colour

from matplotlib import pyplot as plt
import seaborn as sns
car_sales.groupby('Colour').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 90000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00

# %%
car_sales.sum(numeric_only = True)
# Out:
# Odometer (KM)    786014
# Doors                40
# dtype: int64

# %%
car_sales.mean(numeric_only = True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.groupby('Make').mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(['Make', 'Colour']).sum(numeric_only = True)['Doors']
# Out:
# Make    Colour
# BMW     Black     5
# Honda   Blue      8
#         Red       4
# Nissan  White     8
# Toyota  Blue      3
#         Green     4
#         White     8
# Name: Doors, dtype: int64

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.isna().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
car_sales['Odometer Mile'] = car_sales['Odometer (KM)'] / 1.6
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer Mile
# 0  Toyota  White         150043      4   $4,000.00      93776.875
# 1   Honda    Red          87899      4   $5,000.00      54936.875
# 2  Toyota   Blue          32549      3   $7,000.00      20343.125
# 3     BMW  Black          11179      5  $22,000.00       6986.875
# 4  Nissan  White         213095      4   $3,500.00     133184.375
# 5  Toyota  Green          99213      4   $4,500.00      62008.125
# 6   Honda   Blue          45698      4   $7,500.00      28561.250
# 7   Honda   Blue          54738      4   $7,000.00      34211.250
# 8  Toyota  White          60000      4   $6,250.00      37500.000
# 9  Nissan  White          31600      4   $9,700.00      19750.000

# %%
car_sales['Currency'] = "USD"

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer Mile Currency
# 0  Toyota  White         150043      4   $4,000.00      93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00      54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00      20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00       6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00     133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00      62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00      28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00      34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00      37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00      19750.000      USD

# %%
car_sales.rename({'Odometer Mile': 'Odometer (Mile)'}, axis = 1, inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875      USD
# 1   Honda    Red          87899      4   $5,000.00        54936.875      USD
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125      USD
# 3     BMW  Black          11179      5  $22,000.00         6986.875      USD
# 4  Nissan  White         213095      4   $3,500.00       133184.375      USD
# 5  Toyota  Green          99213      4   $4,500.00        62008.125      USD
# 6   Honda   Blue          45698      4   $7,500.00        28561.250      USD
# 7   Honda   Blue          54738      4   $7,000.00        34211.250      USD
# 8  Toyota  White          60000      4   $6,250.00        37500.000      USD
# 9  Nissan  White          31600      4   $9,700.00        19750.000      USD

# %%
car_sales.drop("Odometer (Mile)", axis = 1, inplace = True)
car_sales
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-9c86c3df4db6> in <cell line: 1>()
# ----> 1 car_sales.drop("Odometer (Mile)", axis = 1, inplace = True)
#       2 car_sales
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
car_sales['Odometer (Mile)'] = car_sales['Odometer (KM)'].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Currency  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00      USD        93776.875
# 1   Honda    Red          87899      4   $5,000.00      USD        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00      USD        20343.125
# 3     BMW  Black          11179      5  $22,000.00      USD         6986.875
# 4  Nissan  White         213095      4   $3,500.00      USD       133184.375
# 5  Toyota  Green          99213      4   $4,500.00      USD        62008.125
# 6   Honda   Blue          45698      4   $7,500.00      USD        28561.250
# 7   Honda   Blue          54738      4   $7,000.00      USD        34211.250
# 8  Toyota  White          60000      4   $6,250.00      USD        37500.000
# 9  Nissan  White          31600      4   $9,700.00      USD        19750.000

# %%
car_sales.drop("Currency", axis = 1, inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
def currency(x):
  if "$" in x:
    return "Dollar"
  elif "£" in x:
    return "Pound"
  elif "€" in x:
    return "Euro"
  else:
    return "Unknown"

car_sales['Currency'] = car_sales['Price'].apply(currency)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   $4,000.00        93776.875   Dollar
# 1   Honda    Red          87899      4   $5,000.00        54936.875   Dollar
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125   Dollar
# 3     BMW  Black          11179      5  $22,000.00         6986.875   Dollar
# 4  Nissan  White         213095      4   $3,500.00       133184.375   Dollar
# 5  Toyota  Green          99213      4   $4,500.00        62008.125   Dollar
# 6   Honda   Blue          45698      4   $7,500.00        28561.250   Dollar
# 7   Honda   Blue          54738      4   $7,000.00        34211.250   Dollar
# 8  Toyota  White          60000      4   $6,250.00        37500.000   Dollar
# 9  Nissan  White          31600      4   $9,700.00        19750.000   Dollar

# %%
car_sales[car_sales["Odometer (Mile)"] > 100_000.index]
# Out:
#   File "<ipython-input-30-11a28c9686cb>", line 1
#     car_sales[car_sales["Odometer (Mile)"] > 100_000.index]
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
car_sales.drop(2)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 6   Honda   Blue          45698      4   $7,500.00        28561.250
# 7   Honda   Blue          54738      4   $7,000.00        34211.250
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales[car_sales["Odometer (Mile)"] > 100_000].index
# Out:
# Index([4], dtype='int64')

# %%
car_sales.drop(car_sales[car_sales["Odometer (Mile)"] > 100_000].index).reset_index(drop = True)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Toyota  Green          99213      4   $4,500.00        62008.125
# 5   Honda   Blue          45698      4   $7,500.00        28561.250
# 6   Honda   Blue          54738      4   $7,000.00        34211.250
# 7  Toyota  White          60000      4   $6,250.00        37500.000
# 8  Nissan  White          31600      4   $9,700.00        19750.000

# %%
car_sales.drop(car_sales[car_sales['Colour'] == "Blue"].index)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)
# 0  Toyota  White         150043      4   $4,000.00        93776.875
# 1   Honda    Red          87899      4   $5,000.00        54936.875
# 3     BMW  Black          11179      5  $22,000.00         6986.875
# 4  Nissan  White         213095      4   $3,500.00       133184.375
# 5  Toyota  Green          99213      4   $4,500.00        62008.125
# 8  Toyota  White          60000      4   $6,250.00        37500.000
# 9  Nissan  White          31600      4   $9,700.00        19750.000

# %%
car_sales[(car_sales['Colour'] == 'Blue') | (car_sales['Odometer (KM)'] > 100_000) & (car_sales['Make'] == "Nissan")]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile) Currency
# 2  Toyota   Blue          32549      3  $7,000.00        20343.125   Dollar
# 4  Nissan  White         213095      4  $3,500.00       133184.375   Dollar
# 6   Honda   Blue          45698      4  $7,500.00        28561.250   Dollar
# 7   Honda   Blue          54738      4  $7,000.00        34211.250   Dollar

# %%
car_sales[['Make', 'Colour', "Doors"]]
# Out:
#      Make Colour  Doors
# 0  Toyota  White      4
# 1   Honda    Red      4
# 2  Toyota   Blue      3
# 3     BMW  Black      5
# 4  Nissan  White      4
# 5  Toyota  Green      4
# 6   Honda   Blue      4
# 7   Honda   Blue      4
# 8  Toyota  White      4
# 9  Nissan  White      4

# %%
car_sales.loc[[1, 5]]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile) Currency
# 1   Honda    Red          87899      4  $5,000.00        54936.875   Dollar
# 5  Toyota  Green          99213      4  $4,500.00        62008.125   Dollar

# %%
animals = pd.Series(['cat', 'dog', 'bird', 'panda', 'snake'], index=[0, 3, 9, 8, 3])
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.sort_values(by = 'Odometer (KM)', ascending=True)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile) Currency
# 3     BMW  Black          11179      5  $22,000.00         6986.875   Dollar
# 9  Nissan  White          31600      4   $9,700.00        19750.000   Dollar
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125   Dollar
# 6   Honda   Blue          45698      4   $7,500.00        28561.250   Dollar
# 7   Honda   Blue          54738      4   $7,000.00        34211.250   Dollar
# 8  Toyota  White          60000      4   $6,250.00        37500.000   Dollar
# 1   Honda    Red          87899      4   $5,000.00        54936.875   Dollar
# 5  Toyota  Green          99213      4   $4,500.00        62008.125   Dollar
# 0  Toyota  White         150043      4   $4,000.00        93776.875   Dollar
# 4  Nissan  White         213095      4   $3,500.00       133184.375   Dollar

# %%
car_sales.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile)
# 9  Nissan  White          31600      4  $9,700.00         19750.00
# 7   Honda   Blue          54738      4  $7,000.00         34211.25

# %%
car_sales.dtypes
# Out:
# Make                object
# Colour              object
# Odometer (KM)        int64
# Doors                int64
# Price               object
# Odometer (Mile)    float64
# Currency            object
# dtype: object

# %%
'heyyy'.replace("h", '')
# Out:
# 'eyyy'

# %%
# Out:
# '10'

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex = True).astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   400000        93776.875   Dollar
# 1   Honda    Red          87899      4   500000        54936.875   Dollar
# 2  Toyota   Blue          32549      3   700000        20343.125   Dollar
# 3     BMW  Black          11179      5  2200000         6986.875   Dollar
# 4  Nissan  White         213095      4   350000       133184.375   Dollar
# 5  Toyota  Green          99213      4   450000        62008.125   Dollar
# 6   Honda   Blue          45698      4   750000        28561.250   Dollar
# 7   Honda   Blue          54738      4   700000        34211.250   Dollar
# 8  Toyota  White          60000      4   625000        37500.000   Dollar
# 9  Nissan  White          31600      4   970000        19750.000   Dollar

# %%
car_sales['Price'].dtype
# Out:
# dtype('O')

# %%
car_sales['Price'] = car_sales['Price'] / 100
car_sales
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     170     try:
# --> 171         result = func(left, right)
#     172     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ...

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales-missing-data.csv
# Out:
# --2024-06-25 06:33:28--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘car-sales-missing-data.csv’
#
# car-sales-missing-d 100%[===================>]     287  --.-KB/s    in 0s
#
# 2024-06-25 06:33:29 (3.21 MB/s) - ‘car-sales-missing-data.csv’ saved [287/287]

# %%
car_sales_missing = pd.read_csv('/content/car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales[car_sales['Colour'] == 'Blue']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Odometer (Mile)
# 2  Toyota   Blue          32549      3  $7,000.00        20343.125
# 6   Honda   Blue          45698      4  $7,500.00        28561.250
# 7   Honda   Blue          54738      4  $7,000.00        34211.250

# %%
car_sales[(car_sales['Colour'] == 'Blue') | (car_sales['Price'] > 8000)]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 2  Toyota   Blue          32549      3   7000.0        20343.125   Dollar
# 3     BMW  Black          11179      5  22000.0         6986.875   Dollar
# 6   Honda   Blue          45698      4   7500.0        28561.250   Dollar
# 7   Honda   Blue          54738      4   7000.0        34211.250   Dollar
# 9  Nissan  White          31600      4   9700.0        19750.000   Dollar

# %%
car_sales.drop(9)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875   Dollar
# 1   Honda    Red          87899      4   5000.0        54936.875   Dollar
# 2  Toyota   Blue          32549      3   7000.0        20343.125   Dollar
# 3     BMW  Black          11179      5  22000.0         6986.875   Dollar
# 4  Nissan  White         213095      4   3500.0       133184.375   Dollar
# 5  Toyota  Green          99213      4   4500.0        62008.125   Dollar
# 6   Honda   Blue          45698      4   7500.0        28561.250   Dollar
# 7   Honda   Blue          54738      4   7000.0        34211.250   Dollar
# 8  Toyota  White          60000      4   6250.0        37500.000   Dollar

# %%
car_sales.drop_duplicates(subset = ['Make'])
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875   Dollar
# 1   Honda    Red          87899      4   5000.0        54936.875   Dollar
# 3     BMW  Black          11179      5  22000.0         6986.875   Dollar
# 4  Nissan  White         213095      4   3500.0       133184.375   Dollar

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Odometer (Mile) Currency
# 0  Toyota  White         150043      4   4000.0        93776.875   Dollar
# 1   Honda    Red          87899      4   5000.0        54936.875   Dollar
# 2  Toyota   Blue          32549      3   7000.0        20343.125   Dollar
# 3     BMW  Black          11179      5  22000.0         6986.875   Dollar
# 4  Nissan  White         213095      4   3500.0       133184.375   Dollar
# 5  Toyota  Green          99213      4   4500.0        62008.125   Dollar
# 6   Honda   Blue          45698      4   7500.0        28561.250   Dollar
# 7   Honda   Blue          54738      4   7000.0        34211.250   Dollar
# 8  Toyota  White          60000      4   6250.0        37500.000   Dollar
# 9  Nissan  White          31600      4   9700.0        19750.000   Dollar

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing.dropna(subset = ['Price'])
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Make'].fillna('Missing', inplace = True)
car_sales_missing
# Out:
#       Make Colour  Odometer  Doors    Price
# 0   Toyota  White  150043.0    4.0   $4,000
# 1    Honda    Red   87899.0    4.0   $5,000
# 2   Toyota   Blue       NaN    3.0   $7,000
# 3      BMW  Black   11179.0    5.0  $22,000
# 4   Nissan  White  213095.0    4.0   $3,500
# 5   Toyota  Green       NaN    4.0   $4,500
# 6    Honda    NaN       NaN    4.0   $7,500
# 7    Honda   Blue       NaN    4.0      NaN
# 8   Toyota  White   60000.0    NaN      NaN
# 9  Missing  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Colour'].fillna(car_sales_missing['Colour'].mode()[0], inplace = True)
car_sales_missing
# Out:
#       Make Colour  Odometer  Doors    Price
# 0   Toyota  White  150043.0    4.0   $4,000
# 1    Honda    Red   87899.0    4.0   $5,000
# 2   Toyota   Blue       NaN    3.0   $7,000
# 3      BMW  Black   11179.0    5.0  $22,000
# 4   Nissan  White  213095.0    4.0   $3,500
# 5   Toyota  Green       NaN    4.0   $4,500
# 6    Honda  White       NaN    4.0   $7,500
# 7    Honda   Blue       NaN    4.0      NaN
# 8   Toyota  White   60000.0    NaN      NaN
# 9  Missing  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].mode()[0]
# Out:
# 11179.0

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales.to_excel("my amazing analysis.xlsx")

# %%
pd.concat([car_sales, car_sales_missing], axis = 1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Odometer (Mile)    Make  \
# 0  Toyota  White         150043      4   $4,000.00        93776.875  Toyota
# 1   Honda    Red          87899      4   $5,000.00        54936.875   Honda
# 2  Toyota   Blue          32549      3   $7,000.00        20343.125  Toyota
# 3     BMW  Black          11179      5  $22,000.00         6986.875     BMW
# 4  Nissan  White         213095      4   $3,500.00       133184.375  Nissan
# 5  Toyota  Green          99213      4   $4,500.00        62008.125  Toyota
# 6   Honda   Blue          45698      4   $7,500.00        28561.250   Honda
# 7   Honda   Blue          54738      4   $7,000.00        34211.250   Honda
# 8  Toyota  White          60000      4   $6,250.00        37500.000  Toyota
# 9  Nissan  White          31600      4   $9,700.00        19750.000     NaN
#
#   Colour       Odometer  Doors    Price
# 0  White  150043.000000    4.0   $4,000
# 1    Red   87899.000000    4.0   $5,000
# ...

# %%
df1 = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [4, 5, 6, 7]})
df2 = pd.DataFrame({'AA': [1, 2, 3], 'C': [10, 11, 12]})
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# 3  4  7

# %%
pd.concat([df1, df2])
# Out:
#      A    B   AA     C
# 0  1.0  4.0  NaN   NaN
# 1  2.0  5.0  NaN   NaN
# 2  3.0  6.0  NaN   NaN
# 3  4.0  7.0  NaN   NaN
# 0  NaN  NaN  1.0  10.0
# 1  NaN  NaN  2.0  11.0
# 2  NaN  NaN  3.0  12.0

# %%
pd.merge(df1, df2, left_on = "A", right_on = "AA", how = 'right')
# Out:
#    A  B   AA     C
# 0  1  4  1.0  10.0
# 1  2  5  2.0  11.0
# 2  3  6  3.0  12.0
# 3  4  7  NaN   NaN

# %%
df1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df2
# Out:
#    A   C
# 0  1  10
# 1  2  11
# 2  3  12

# %%
pd.crosstab(car_sales['Make'], car_sales['Colour'])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2
